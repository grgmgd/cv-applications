# %% [markdown]
# # Optimal Thresholding Segmentation
#
#
# #### Contributors:
# | Name   |      IDs      |
# |----------|:-------------:|
# | George Magued |  37 - 0930 |
# | Youssef Tarek Salah El Dine | 37-3865 |

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.image as matimage
import imageio

# %%
guc = plt.imread("images/guc.jpg")
plt.imshow(guc, cmap="gray")

# %%
def optimal_thresholding(image, n):
    min = image.min()
    max = image.max()
    
    thresholds = np.insert(np.linspace(min, max, n, endpoint=False).astype(int), n, max) 
    while(True):
        segment_means = np.empty(n)
        for i in range(n):
            segment_means[i] = image[(image >= thresholds[i]) & (image < thresholds[i + 1])].mean().astype(int)
        new_thresholds = np.empty(n - 1)
        for i in range(n - 1):
            new_thresholds[i] = (segment_means[i] + segment_means[i + 1]) // 2
        new_thresholds = np.insert(np.sort(new_thresholds), [0, n - 1], [min, max]).astype(int)
        if(np.array_equal(thresholds, new_thresholds)):
            break
        thresholds = new_thresholds.copy()
    x, y = image.shape
    segments = np.empty((n, x, y))
    for i in range(n):
        segments[i] = np.where(((image >= thresholds[i]) & (image < thresholds[i + 1])), 1, 0)
    return segments, thresholds

# %%
def segment_image(image, n, name):
    thresholds = n + 1
    segments, updated_thresholds = optimal_thresholding(guc, thresholds)
    segmented_image = np.empty(image.shape)
    colors = np.linspace(0, 255, thresholds, endpoint=True)
    for i in range(thresholds):
        segment = segments[i]
        segmented_image = segmented_image + np.where(segment != 0, colors[i], 0)
        plt.imsave(f'output/optimal_thresholding/{name}_{n}_{i+1}.jpg', segments[i], cmap="gray")
    np.savetxt(f'output/optimal_thresholding/Thresholds_{n}.txt', updated_thresholds[1:], fmt='%d')
    plot_segments(segments, segmented_image, updated_thresholds)
    plt.imsave(f'output/optimal_thresholding/{name}_{n}.jpg', segmented_image, cmap="gray")

# %%
def plot_segments(segments, segment_image, thresholds):
    fig = plt.figure(figsize=(10, 5), constrained_layout=True)
    gs = fig.add_gridspec(nrows=2, ncols=segments.shape[0])

    for i in range(segments.shape[0]):
        ax = fig.add_subplot(gs[:-1, i])
        ax.set_title("≤ "+str(thresholds[i+1]))
        ax.axis("off")
        ax.imshow(segments[i], cmap='gray')

    ax = fig.add_subplot(gs[-1, :])
    ax.axis("off")
    ax.imshow(segment_image, cmap="gray")

# %% [markdown]
# Below we will call the function with the original **image** = `guc` and with **n** = `3`.
#
# Outputs were 4 images representing the updated means among clustered threshold intervals. <br>
# [0 to **v1**] _represents_ **darkest** values in the image. <br>
# [**v1** to **v2**] _represents_ **brigher darkest** values in the image. <br>
# [**v2** to **v3**] _represents_ **darker brightest** in the image. <br>
# [**v3** to 255] _represents_ **brightest** values in the image.

# %%
segment_image(guc, 3, "GUC")

# %% [markdown]
# Below we will call the function with the original **image** = `guc` and with **n** = `4`.
#
# Outputs were 5 images representing the updated means among clustered threshold intervals. <br>
# [0 to **v1**] _represents_ **darkest** values in the image. <br>
# [**v1** to **v2**] _represents_ **brigher darkest** values in the image. <br>
# [**v2** to **v3**] _represents_ **mid** in the image. <br>
# [**v3** to **v4**] _represents_ **darker brightest** values in the image. <br>
# [**v4** to 255] _represents_ **brightest** values in the image.

# %%
segment_image(guc, 4, "GUC")
